# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED hanrath_type_2022: " Type {I} interferon receptor ({IFNAR2}) deficiency reveals { ... "
# SUCESSFULLY PARSED sen_quantitative_2022: " Quantitative modeling of human liver reveals dysregulation o ... "
# SUCESSFULLY PARSED james_integration_2022: " Integration of probabilistic functional networks without an  ... "
# SUCESSFULLY PARSED james_expanding_2022: " Expanding interactome analyses beyond model eukaryotes  "
# SUCESSFULLY PARSED datta_mechanical-stress-related_2022: " Mechanical-{Stress}-{Related} {Epigenetic} {Regulation} of { ... "
# SUCESSFULLY PARSED donaghy_blood_2022: " Blood {mRNA} {Expression} in {Alzheimer}'s {Disease} and {De ... "
# SUCESSFULLY PARSED johnson_increased_2022: " Increased serum {miR}-193a-5p during non-alcoholic fatty liv ... "
# SUCESSFULLY PARSED oud_novo_2022: " A de novo paradigm for male infertility  "
# SUCESSFULLY PARSED masi_distinct_2021: " Distinct gene expression profiles between human preterm-deri ... "
# SUCESSFULLY PARSED sadegh_network_2021: " Network medicine for disease module identification and drug  ... "
# SUCESSFULLY PARSED kozumi_transcriptomics_2021: " Transcriptomics {Identify} {Thrombospondin}-2 as a {Biomarke ... "
# SUCESSFULLY PARSED addison_therapeutic_2021: " Therapeutic wavelengths of ultraviolet {B} radiation activat ... "
# SUCESSFULLY PARSED pfister_nash_2021: " {NASH} limits anti-tumour surveillance in immunotherapy-trea ... "
# SUCESSFULLY PARSED govaere_transcriptomic_2020: " Transcriptomic profiling across the nonalcoholic fatty liver ... "
# SUCESSFULLY PARSED ball_microarray_2020: " Microarray analysis of primary epithelial and fibroblast cel ... "
# SUCESSFULLY PARSED anstee_genome-wide_2020: " Genome-wide association study of non-alcoholic fatty liver a ... "
# SUCESSFULLY PARSED cheung_correlation_2020: " Correlation of {Infinium} {HumanMethylation450K} and {Methyl ... "
# SUCESSFULLY PARSED zerti_understanding_2020: " Understanding the complexity of retina and pluripotent stem  ... "
# SUCESSFULLY PARSED davies_epigenetic_2019: " Epigenetic modifiers {DNMT3A} and {BCOR} are recurrently mut ... "
# SUCESSFULLY PARSED munkley_androgen-regulated_2019: " Androgen-regulated transcription of {ESRP2} drives alternati ... "
# SUCESSFULLY PARSED phillips_pax9_2019: " Pax9 is required for cardiovascular development and interact ... "
# SUCESSFULLY PARSED ehrmann_ancient_2019: " An ancient germ cell-specific {RNA}-binding protein protects ... "
# SUCESSFULLY PARSED govaere_high-throughput_2019: " High-throughput sequencing identifies aetiology-dependent di ... "
# SUCESSFULLY PARSED collin_deconstructing_2019: " Deconstructing {Retinal} {Organoids}: {Single} {Cell} {RNA}- ... "
# SUCESSFULLY PARSED szoltysek_rrad_2018: " {RRAD}, {IL4I1}, {CDKN1A}, and {SERPINE1} genes are potentia ... "
# SUCESSFULLY PARSED james_b-cell_2018: " B-cell activity markers are associated with different diseas ... "
# SUCESSFULLY PARSED janus_pro-inflammatory_2018: " Pro-inflammatory cytokine and high doses of ionizing radiati ... "
# SUCESSFULLY PARSED pease_cross_2017: " Cross platform analysis of transcriptomic data identifies ag ... "
# SUCESSFULLY PARSED donadio_influence_2017: " Influence of {Genetic} {Variations} in {Selenoprotein} {Gene ... "
# SUCESSFULLY PARSED elder_abundant_2017: " Abundant and equipotent founder cells establish and maintain ... "
# SUCESSFULLY PARSED james_deep_2017: " Deep sequencing approaches for the analysis of prokaryotic t ... "
# SUCESSFULLY PARSED james_misincorporation_2017: " Misincorporation by {RNA} polymerase is a major source of tr ... "
# SUCESSFULLY PARSED khundakar_analysis_2016: " Analysis of primary visual cortex in dementia with {Lewy} bo ... "
# SUCESSFULLY PARSED mullen_integrated_2016: " An {Integrated} {Data} {Driven} {Approach} to {Drug} {Reposi ... "
# SUCESSFULLY PARSED meplan_transcriptomics_2016: " Transcriptomics and proteomics show that selenium affects in ... "
# SUCESSFULLY PARSED moles_relap65_2016: " A {RelA}(p65) {Thr505} phospho-site mutation reveals an impo ... "
# SUCESSFULLY PARSED mullen_mining_2016: " Mining integrated semantic networks for drug repositioning o ... "
# SUCESSFULLY PARSED hardyman_zinc_2016: " Zinc sensing by metal-responsive transcription factor 1 ({MT ... "
# SUCESSFULLY PARSED james_transcriptional_2015: " A {Transcriptional} {Signature} of {Fatigue} {Derived} from  ... "
# SUCESSFULLY PARSED hunter_nf-b_2016: " The {NF}-κ{B} subunit c-{Rel} regulates {Bach2} tumour suppr ... "
# SUCESSFULLY PARSED manville_genome-wide_2015: " Genome-wide {ChIP}-seq analysis of human {TOP2B} occupancy i ... "
# SUCESSFULLY PARSED dubarry_genetic_2015: " Genetic {Networks} {Required} to {Coordinate} {Chromosome} { ... "
# SUCESSFULLY PARSED gabriel_epigenetic_2015: " Epigenetic landscape correlates with genetic subtype but doe ... "
# SUCESSFULLY PARSED wakeling_sirt1_2015: " {SIRT1} affects {DNA} methylation of polycomb group protein  ... "
# SUCESSFULLY PARSED ogo_zinc_2015: " The zinc finger protein {ZNF658} regulates the transcription ... "
# SUCESSFULLY PARSED flanagan_distributed_2014: " A distributed computational search strategy for the identifi ... "
# SUCESSFULLY PARSED werner_contribution_2014: " Contribution of natural antisense transcription to an endoge ... "
# SUCESSFULLY PARSED probert_utility_2014: " Utility of {B}-13 progenitor-derived hepatocytes in hepatoto ... "
# SUCESSFULLY PARSED lee_mre11_2012: " {MRE11} facilitates the removal of human topoisomerase {II}  ... "
# SUCESSFULLY PARSED weile_bayesian_2012: " Bayesian integration of networks without gold standards  "
# SUCESSFULLY PARSED parnell_biostar_2011: " {BioStar}: an online question \& answer resource for the bio ... "
# SUCESSFULLY PARSED stadler_structure-function_2011: " Structure-function studies of an engineered scaffold protein ... "
# SUCESSFULLY PARSED weile_customizable_2011: " Customizable views on semantically integrated networks for s ... "
# SUCESSFULLY PARSED hoogland_guidelines_2010: " Guidelines for reporting the use of gel image informatics in ... "
# SUCESSFULLY PARSED emami_changes_2010: " Changes in protein expression profiles between a low phytic  ... "
# SUCESSFULLY PARSED cockell_integrated_2010: " An integrated dataset for in silico drug discovery  "
# SUCESSFULLY PARSED cockell_structure-based_2007: " Structure-based evaluation of in silico predictions of prote ... "
